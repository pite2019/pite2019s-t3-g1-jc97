# %%
import sklearn
import sklearn.datasets
from sklearn import linear_model
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
# %matplotlib inline
boston = load_boston()
panda_data_frame = pd.DataFrame(boston.data)
panda_data_frame.columns = boston.feature_names
print(panda_data_frame.head())
hist= panda_data_frame.hist(column='AGE')
hist= panda_data_frame.hist(column='TAX')
target = pd.DataFrame(boston.target, columns=["MDEV"])
y=target["MDEV"]
LR = linear_model.LinearRegression().fit(panda_data_frame, y)
predictions = LR.predict(panda_data_frame)
print(predictions)[0:4]
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33
# [ 30.00821269  25.0298606   30.5702317   28.60814055  27.94288232
#   25.25940048  23.00433994  19.5347558   11.51696539  18.91981483
#   18.9958266   21.58970854  20.90534851  19.55535931  19.2837957
#   19.30000174  20.52889993  16.9096749   16.17067411  18.40781636
#   12.52040454  17.67104565  15.82934891  13.80368317  15.67708138
# ...
